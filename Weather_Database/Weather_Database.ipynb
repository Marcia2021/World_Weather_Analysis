# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | lagoa
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | urozhaynoye
# Processing Record 6 of Set 1 | medvedka
# Processing Record 7 of Set 1 | sao jose da coroa grande
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | sibolga
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | vila franca do campo
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | puerto carreno
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | pangnirtung
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | pyapon
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | ahuimanu
# Processing Record 25 of Set 1 | edson
# Processing Record 26 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | riyadh
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | alta floresta
# Processing Record 32 of Set 1 | haimen
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | alto araguaia
# Processing Record 35 of Set 1 | ketchikan
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | hobyo
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | high level
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | beringovskiy
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | susurluk
# Processing Record 47 of Set 1 | umtata
# Processing Record 48 of Set 1 | akkudah
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | namibe
# Processing Record 1 of Set 2 | baracoa
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | xai-xai
# Processing Record 6 of Set 2 | khandyga
# Processing Record 7 of Set 2 | cassilandia
# Processing Record 8 of Set 2 | byron bay
# Processing Record 9 of Set 2 | lebedinyy
# Processing Record 10 of Set 2 | dondo
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | sabang
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | jiazi
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | fort nelson
# Processing Record 19 of Set 2 | gilgit
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | dubbo
# Processing Record 22 of Set 2 | skibbereen
# Processing Record 23 of Set 2 | smithers
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | egvekinot
# Processing Record 26 of Set 2 | ngaoundere
# Processing Record 27 of Set 2 | tirat karmel
# Processing Record 28 of Set 2 | saint-joseph
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | karratha
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | rio gallegos
# Processing Record 34 of Set 2 | kendari
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 2 | akdepe
# Processing Record 38 of Set 2 | moses lake
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | pandan
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | uruzgan
# Processing Record 44 of Set 2 | port hardy
# Processing Record 45 of Set 2 | luwuk
# Processing Record 46 of Set 2 | vanimo
# Processing Record 47 of Set 2 | sisimiut
# Processing Record 48 of Set 2 | aitape
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | lluta
# Processing Record 2 of Set 3 | gurlan
# Processing Record 3 of Set 3 | gravdal
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | meadow lake
# Processing Record 7 of Set 3 | bay roberts
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | mount isa
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | port macquarie
# Processing Record 14 of Set 3 | banikoara
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | lanzhou
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | husavik
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | nova soure
# Processing Record 28 of Set 3 | arman
# Processing Record 29 of Set 3 | college
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | saint paul
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | marsh harbour
# Processing Record 34 of Set 3 | shipitsyno
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | turgoyak
# Processing Record 37 of Set 3 | sao caetano de odivelas
# Processing Record 38 of Set 3 | haines junction
# Processing Record 39 of Set 3 | del rio
# Processing Record 40 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 3 | bataipora
# Processing Record 42 of Set 3 | mitzic
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 3 | tautira
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | zhanaozen
# Processing Record 48 of Set 3 | basudebpur
# Processing Record 49 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | quarai
# Processing Record 5 of Set 4 | sherlovaya gora
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | manali
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | sakaiminato
# Processing Record 11 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 4 | itarema
# Processing Record 13 of Set 4 | butembo
# Processing Record 14 of Set 4 | aktau
# Processing Record 15 of Set 4 | kamenka
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | taganak
# Processing Record 18 of Set 4 | vikulovo
# Processing Record 19 of Set 4 | kutum
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | yellowknife
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | beloha
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | comodoro rivadavia
# Processing Record 27 of Set 4 | san-pedro
# Processing Record 28 of Set 4 | portland
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | trincomalee
# Processing Record 31 of Set 4 | henties bay
# Processing Record 32 of Set 4 | bluff
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | tateyama
# Processing Record 35 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 36 of Set 4 | long
# Processing Record 37 of Set 4 | yeppoon
# Processing Record 38 of Set 4 | roswell
# Processing Record 39 of Set 4 | shimoda
# Processing Record 40 of Set 4 | lavrentiya
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | murgab
# Processing Record 43 of Set 4 | gamba
# Processing Record 44 of Set 4 | verkhnyaya inta
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | lasa
# Processing Record 49 of Set 4 | tumen
# Processing Record 50 of Set 4 | sheridan
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | kapaa
# Processing Record 3 of Set 5 | yeniseysk
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | bismarck
# Processing Record 6 of Set 5 | kasempa
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | guiglo
# Processing Record 9 of Set 5 | mahon
# Processing Record 10 of Set 5 | kozhva
# Processing Record 11 of Set 5 | alice springs
# Processing Record 12 of Set 5 | champerico
# Processing Record 13 of Set 5 | yulara
# Processing Record 14 of Set 5 | xalpatlahuac
# Processing Record 15 of Set 5 | valparaiso
# Processing Record 16 of Set 5 | tokmak
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | vulcan
# Processing Record 19 of Set 5 | maxixe
# Processing Record 20 of Set 5 | guadalajara
# Processing Record 21 of Set 5 | hare bay
# Processing Record 22 of Set 5 | manggar
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | chumikan
# Processing Record 25 of Set 5 | guerrero negro
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | san quintin
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | frome
# Processing Record 30 of Set 5 | aljezur
# Processing Record 31 of Set 5 | komlo
# Processing Record 32 of Set 5 | oncesti
# Processing Record 33 of Set 5 | torbay
# Processing Record 34 of Set 5 | broken hill
# Processing Record 35 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 5 | ulladulla
# Processing Record 37 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint anthony
# Processing Record 39 of Set 5 | bom jesus
# Processing Record 40 of Set 5 | chameza
# City not found. Skipping...
# Processing Record 41 of Set 5 | kokopo
# Processing Record 42 of Set 5 | kokoda
# Processing Record 43 of Set 5 | ucluelet
# Processing Record 44 of Set 5 | bukama
# Processing Record 45 of Set 5 | brae
# Processing Record 46 of Set 5 | mersing
# Processing Record 47 of Set 5 | deder
# Processing Record 48 of Set 5 | harsud
# Processing Record 49 of Set 5 | marawi
# Processing Record 50 of Set 5 | tabou
# Processing Record 1 of Set 6 | walvis bay
# Processing Record 2 of Set 6 | tambovka
# Processing Record 3 of Set 6 | los banos
# Processing Record 4 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 5 of Set 6 | great falls
# Processing Record 6 of Set 6 | roebourne
# Processing Record 7 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 6 | georgetown
# Processing Record 9 of Set 6 | sinnamary
# Processing Record 10 of Set 6 | susah
# City not found. Skipping...
# Processing Record 11 of Set 6 | winton
# Processing Record 12 of Set 6 | west wendover
# Processing Record 13 of Set 6 | filadelfia
# Processing Record 14 of Set 6 | san miguel
# Processing Record 15 of Set 6 | namie
# Processing Record 16 of Set 6 | alofi
# Processing Record 17 of Set 6 | hirara
# Processing Record 18 of Set 6 | chimbote
# Processing Record 19 of Set 6 | goundam
# Processing Record 20 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 6 | chino valley
# Processing Record 22 of Set 6 | dunmanway
# Processing Record 23 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 6 | iquique
# Processing Record 25 of Set 6 | conceicao do araguaia
# Processing Record 26 of Set 6 | hualmay
# Processing Record 27 of Set 6 | saskylakh
# Processing Record 28 of Set 6 | grand gaube
# Processing Record 29 of Set 6 | mayumba
# Processing Record 30 of Set 6 | yekaterinoslavka
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | laguna de perlas
# Processing Record 33 of Set 6 | curup
# Processing Record 34 of Set 6 | batagay
# Processing Record 35 of Set 6 | cheremukhovo
# Processing Record 36 of Set 6 | kavieng
# Processing Record 37 of Set 6 | turkmenabat
# Processing Record 38 of Set 6 | quatre cocos
# Processing Record 39 of Set 6 | sorland
# Processing Record 40 of Set 6 | ulaangom
# Processing Record 41 of Set 6 | dalvik
# Processing Record 42 of Set 6 | pochutla
# Processing Record 43 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | makakilo city
# Processing Record 46 of Set 6 | clearwater
# Processing Record 47 of Set 6 | itambe
# Processing Record 48 of Set 6 | alizai
# Processing Record 49 of Set 6 | yarim
# Processing Record 50 of Set 6 | jiuquan
# Processing Record 1 of Set 7 | chicla
# Processing Record 2 of Set 7 | coihaique
# Processing Record 3 of Set 7 | monrovia
# Processing Record 4 of Set 7 | ponta delgada
# Processing Record 5 of Set 7 | qandala
# Processing Record 6 of Set 7 | yoichi
# Processing Record 7 of Set 7 | deniliquin
# Processing Record 8 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 7 | pasighat
# Processing Record 10 of Set 7 | aden
# Processing Record 11 of Set 7 | mosquera
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | hofn
# Processing Record 14 of Set 7 | palmas
# Processing Record 15 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 7 | mardin
# Processing Record 17 of Set 7 | agadez
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | olinda
# Processing Record 21 of Set 7 | bud
# Processing Record 22 of Set 7 | north bend
# Processing Record 23 of Set 7 | plettenberg bay
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | lowestoft
# Processing Record 26 of Set 7 | dubovskoye
# Processing Record 27 of Set 7 | mezen
# Processing Record 28 of Set 7 | manjacaze
# Processing Record 29 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | barrow
# Processing Record 31 of Set 7 | tepechitlan
# Processing Record 32 of Set 7 | kalmunai
# Processing Record 33 of Set 7 | bull savanna
# Processing Record 34 of Set 7 | gigmoto
# Processing Record 35 of Set 7 | cabul-an
# Processing Record 36 of Set 7 | kiama
# Processing Record 37 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 38 of Set 7 | porto novo
# Processing Record 39 of Set 7 | banda aceh
# Processing Record 40 of Set 7 | salina cruz
# Processing Record 41 of Set 7 | karnobat
# Processing Record 42 of Set 7 | ust-ishim
# Processing Record 43 of Set 7 | sakakah
# Processing Record 44 of Set 7 | ajdabiya
# Processing Record 45 of Set 7 | new milford
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | constitucion
# Processing Record 48 of Set 7 | sestroretsk
# Processing Record 49 of Set 7 | ambilobe
# Processing Record 50 of Set 7 | nizwa
# Processing Record 1 of Set 8 | gladstone
# Processing Record 2 of Set 8 | yumen
# Processing Record 3 of Set 8 | salinopolis
# Processing Record 4 of Set 8 | poum
# Processing Record 5 of Set 8 | gat
# Processing Record 6 of Set 8 | nome
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | mana
# Processing Record 9 of Set 8 | benguela
# Processing Record 10 of Set 8 | ossora
# Processing Record 11 of Set 8 | flin flon
# Processing Record 12 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 8 | belaya gora
# Processing Record 14 of Set 8 | ipu
# Processing Record 15 of Set 8 | saint-pierre
# Processing Record 16 of Set 8 | jacareacanga
# Processing Record 17 of Set 8 | beidao
# Processing Record 18 of Set 8 | yatou
# Processing Record 19 of Set 8 | gornyy
# Processing Record 20 of Set 8 | vardo
# Processing Record 21 of Set 8 | vagur
# Processing Record 22 of Set 8 | charters towers
# Processing Record 23 of Set 8 | hailar
# Processing Record 24 of Set 8 | luanda
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | longkou
# Processing Record 27 of Set 8 | bahia honda
# Processing Record 28 of Set 8 | halifax
# Processing Record 29 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 8 | youghal
# Processing Record 31 of Set 8 | adra
# Processing Record 32 of Set 8 | sao sebastiao
# Processing Record 33 of Set 8 | warangal
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | latung
# Processing Record 36 of Set 8 | lewiston
# Processing Record 37 of Set 8 | buala
# Processing Record 38 of Set 8 | hami
# Processing Record 39 of Set 8 | kirakira
# Processing Record 40 of Set 8 | pangai
# Processing Record 41 of Set 8 | ternate
# Processing Record 42 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 8 | narsaq
# Processing Record 44 of Set 8 | zamora
# Processing Record 45 of Set 8 | mahibadhoo
# Processing Record 46 of Set 8 | usevya
# Processing Record 47 of Set 8 | mut
# Processing Record 48 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 8 | saiha
# Processing Record 50 of Set 8 | pangody
# Processing Record 1 of Set 9 | aktyubinskiy
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | ust-maya
# Processing Record 4 of Set 9 | nantucket
# Processing Record 5 of Set 9 | laguna
# Processing Record 6 of Set 9 | alikalia
# Processing Record 7 of Set 9 | tarko-sale
# Processing Record 8 of Set 9 | qesarya
# Processing Record 9 of Set 9 | albion
# Processing Record 10 of Set 9 | skagen
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | orlik
# Processing Record 13 of Set 9 | wenling
# Processing Record 14 of Set 9 | tankhoy
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | shelburne
# Processing Record 17 of Set 9 | bethanien
# Processing Record 18 of Set 9 | taiyuan
# Processing Record 19 of Set 9 | shubarshi
# Processing Record 20 of Set 9 | buraydah
# Processing Record 21 of Set 9 | general roca
# Processing Record 22 of Set 9 | viedma
# Processing Record 23 of Set 9 | fortuna
# Processing Record 24 of Set 9 | san jose
# Processing Record 25 of Set 9 | hohhot
# Processing Record 26 of Set 9 | ostrovnoy
# Processing Record 27 of Set 9 | hovd
# Processing Record 28 of Set 9 | bagotville
# Processing Record 29 of Set 9 | pirassununga
# Processing Record 30 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 9 | erenhot
# Processing Record 32 of Set 9 | namatanai
# Processing Record 33 of Set 9 | edmundston
# Processing Record 34 of Set 9 | klaksvik
# Processing Record 35 of Set 9 | itupiranga
# Processing Record 36 of Set 9 | saint-georges
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | nador
# Processing Record 39 of Set 9 | angoche
# Processing Record 40 of Set 9 | alekseyevsk
# Processing Record 41 of Set 9 | boone
# Processing Record 42 of Set 9 | half moon bay
# Processing Record 43 of Set 9 | port moresby
# Processing Record 44 of Set 9 | isangel
# Processing Record 45 of Set 9 | saint john
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | miandrivazo
# Processing Record 48 of Set 9 | bambous virieux
# Processing Record 49 of Set 9 | harrisburg
# Processing Record 50 of Set 9 | bowling green
# Processing Record 1 of Set 10 | emerald
# Processing Record 2 of Set 10 | sabha
# Processing Record 3 of Set 10 | bang saphan
# Processing Record 4 of Set 10 | vallenar
# Processing Record 5 of Set 10 | monmouth
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | boguchany
# Processing Record 8 of Set 10 | macomb
# Processing Record 9 of Set 10 | paamiut
# Processing Record 10 of Set 10 | merauke
# Processing Record 11 of Set 10 | dunedin
# Processing Record 12 of Set 10 | nacimiento
# Processing Record 13 of Set 10 | arraial do cabo
# Processing Record 14 of Set 10 | bosaso
# Processing Record 15 of Set 10 | nyurba
# Processing Record 16 of Set 10 | nemuro
# Processing Record 17 of Set 10 | rondonopolis
# Processing Record 18 of Set 10 | sargur
# Processing Record 19 of Set 10 | venado
# Processing Record 20 of Set 10 | nikki
# Processing Record 21 of Set 10 | tarpon springs
# Processing Record 22 of Set 10 | aguie
# Processing Record 23 of Set 10 | nogent-le-rotrou
# Processing Record 24 of Set 10 | san cristobal
# Processing Record 25 of Set 10 | qinhuangdao
# Processing Record 26 of Set 10 | de-kastri
# Processing Record 27 of Set 10 | casablanca
# Processing Record 28 of Set 10 | nago
# Processing Record 29 of Set 10 | olden
# Processing Record 30 of Set 10 | faya
# Processing Record 31 of Set 10 | decatur
# Processing Record 32 of Set 10 | kenai
# Processing Record 33 of Set 10 | erzin
# Processing Record 34 of Set 10 | berlevag
# Processing Record 35 of Set 10 | sao filipe
# Processing Record 36 of Set 10 | cubuk
# Processing Record 37 of Set 10 | skjervoy
# Processing Record 38 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 10 | shadegan
# Processing Record 40 of Set 10 | louis trichardt
# Processing Record 41 of Set 10 | nelson bay
# Processing Record 42 of Set 10 | hisua
# Processing Record 43 of Set 10 | seoul
# Processing Record 44 of Set 10 | ranau
# Processing Record 45 of Set 10 | pipirig
# Processing Record 46 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 10 | sur
# Processing Record 48 of Set 10 | oranjestad
# Processing Record 49 of Set 10 | te anau
# Processing Record 50 of Set 10 | khomeynishahr
# City not found. Skipping...
# Processing Record 1 of Set 11 | vostok
# Processing Record 2 of Set 11 | turukhansk
# Processing Record 3 of Set 11 | sitka
# Processing Record 4 of Set 11 | mogzon
# Processing Record 5 of Set 11 | trairi
# Processing Record 6 of Set 11 | caravelas
# Processing Record 7 of Set 11 | los llanos de aridane
# Processing Record 8 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 11 | khotyn
# Processing Record 10 of Set 11 | aykhal
# Processing Record 11 of Set 11 | mahebourg
# Processing Record 12 of Set 11 | skeldon
# Processing Record 13 of Set 11 | muleba
# Processing Record 14 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 11 | puerto colombia
# Processing Record 16 of Set 11 | atasu
# Processing Record 17 of Set 11 | vaitape
# Processing Record 18 of Set 11 | rocha
# Processing Record 19 of Set 11 | huancavelica
# Processing Record 20 of Set 11 | honavar
# Processing Record 21 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 11 | hanmer springs
# Processing Record 23 of Set 11 | sallanches
# Processing Record 24 of Set 11 | phan thiet
# Processing Record 25 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 11 | luau
# Processing Record 27 of Set 11 | santa rosa
# Processing Record 28 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 29 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 11 | gorlice
# Processing Record 31 of Set 11 | maiduguri
# Processing Record 32 of Set 11 | griffith
# Processing Record 33 of Set 11 | vila do maio
# Processing Record 34 of Set 11 | hereford
# Processing Record 35 of Set 11 | arosa
# Processing Record 36 of Set 11 | whitehorse
# Processing Record 37 of Set 11 | sao joao da barra
# Processing Record 38 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 39 of Set 11 | kudahuvadhoo
# Processing Record 40 of Set 11 | garissa
# Processing Record 41 of Set 11 | great yarmouth
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | thinadhoo
# Processing Record 44 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 11 | taber
# Processing Record 46 of Set 11 | port blair
# Processing Record 47 of Set 11 | uyuni
# Processing Record 48 of Set 11 | alappuzha
# Processing Record 49 of Set 11 | moose factory
# Processing Record 50 of Set 11 | ust-nera
# Processing Record 1 of Set 12 | robertsport
# Processing Record 2 of Set 12 | lokosovo
# Processing Record 3 of Set 12 | araouane
# Processing Record 4 of Set 12 | sao gabriel da cachoeira
# Processing Record 5 of Set 12 | malm
# Processing Record 6 of Set 12 | okha
# Processing Record 7 of Set 12 | zarate
# Processing Record 8 of Set 12 | khajuraho
# Processing Record 9 of Set 12 | waingapu
# Processing Record 10 of Set 12 | vangaindrano
# Processing Record 11 of Set 12 | doka
# Processing Record 12 of Set 12 | yermakovskoye
# Processing Record 13 of Set 12 | noumea
# Processing Record 14 of Set 12 | bereda
# Processing Record 15 of Set 12 | isla mujeres
# Processing Record 16 of Set 12 | luganville
# Processing Record 17 of Set 12 | dongsheng
# Processing Record 18 of Set 12 | zdvinsk
# Processing Record 19 of Set 12 | zhigansk
# Processing Record 20 of Set 12 | flagstaff
# Processing Record 21 of Set 12 | luang prabang
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | timbiqui
# Processing Record 24 of Set 12 | camopi
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | nadym
# Processing Record 27 of Set 12 | verkhoyansk
# Processing Record 28 of Set 12 | cockburn town
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | mattru
# Processing Record 31 of Set 12 | ormara
# Processing Record 32 of Set 12 | tazovskiy
# Processing Record 33 of Set 12 | bogande
# Processing Record 34 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 35 of Set 12 | merrill
# Processing Record 36 of Set 12 | cayenne
# Processing Record 37 of Set 12 | preobrazheniye
# Processing Record 38 of Set 12 | burica
# City not found. Skipping...
# Processing Record 39 of Set 12 | tchollire
# Processing Record 40 of Set 12 | labuan
# Processing Record 41 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 42 of Set 12 | cabinda
# Processing Record 43 of Set 12 | show low
# Processing Record 44 of Set 12 | maldonado
# Processing Record 45 of Set 12 | bandarbeyla
# Processing Record 46 of Set 12 | novichikha
# Processing Record 47 of Set 12 | yerbogachen
# Processing Record 48 of Set 12 | pauini
# Processing Record 49 of Set 12 | bambanglipuro
# Processing Record 50 of Set 12 | evans
# Processing Record 1 of Set 13 | senneterre
# Processing Record 2 of Set 13 | badou
# Processing Record 3 of Set 13 | guozhen
# Processing Record 4 of Set 13 | san fernando
# Processing Record 5 of Set 13 | marfino
# Processing Record 6 of Set 13 | nha trang
# Processing Record 7 of Set 13 | bairiki
# Processing Record 8 of Set 13 | do gonbadan
# Processing Record 9 of Set 13 | kozarmisleny
# Processing Record 10 of Set 13 | gunjur
# Processing Record 11 of Set 13 | nuuk
# Processing Record 12 of Set 13 | texarkana
# Processing Record 13 of Set 13 | hat yai
# Processing Record 14 of Set 13 | ugoofaaru
# Processing Record 15 of Set 13 | gayeri
# Processing Record 16 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 13 | okhotsk
# Processing Record 18 of Set 13 | ust-ilimsk
# Processing Record 19 of Set 13 | kapuskasing
# Processing Record 20 of Set 13 | zhicheng
# Processing Record 21 of Set 13 | payo
# Processing Record 22 of Set 13 | nurlat
# Processing Record 23 of Set 13 | ishigaki
# Processing Record 24 of Set 13 | kuhestan
# City not found. Skipping...
# Processing Record 25 of Set 13 | anadyr
# Processing Record 26 of Set 13 | kalmanka
# Processing Record 27 of Set 13 | sola
# Processing Record 28 of Set 13 | morales
# Processing Record 29 of Set 13 | hit
# Processing Record 30 of Set 13 | hasaki
# Processing Record 31 of Set 13 | luohe
# Processing Record 32 of Set 13 | oyama
# Processing Record 33 of Set 13 | havre-saint-pierre
# Processing Record 34 of Set 13 | le port
# Processing Record 35 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 13 | tual
# Processing Record 37 of Set 13 | codrington
# Processing Record 38 of Set 13 | port hedland
# Processing Record 39 of Set 13 | tabuk
# Processing Record 40 of Set 13 | asau
# Processing Record 41 of Set 13 | waitati
# Processing Record 42 of Set 13 | waipawa
# Processing Record 43 of Set 13 | valley city
# Processing Record 44 of Set 13 | kyren
# Processing Record 45 of Set 13 | jalu
# Processing Record 46 of Set 13 | khash
# Processing Record 47 of Set 13 | pacific grove
# Processing Record 48 of Set 13 | deputatskiy
# Processing Record 49 of Set 13 | mabaruma
# Processing Record 50 of Set 13 | kampot
# Processing Record 1 of Set 14 | iskateley
# Processing Record 2 of Set 14 | houma
# Processing Record 3 of Set 14 | santa isabel do rio negro
# Processing Record 4 of Set 14 | camocim
# Processing Record 5 of Set 14 | tessalit
# Processing Record 6 of Set 14 | tignere
# Processing Record 7 of Set 14 | atherton
# Processing Record 8 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 14 | kuryk
# Processing Record 10 of Set 14 | pak phanang
# Processing Record 11 of Set 14 | atar
# Processing Record 12 of Set 14 | mallama
# City not found. Skipping...
# Processing Record 13 of Set 14 | nurota
# Processing Record 14 of Set 14 | iralaya
# Processing Record 15 of Set 14 | aragats
# Processing Record 16 of Set 14 | zyryanka
# Processing Record 17 of Set 14 | bhadrachalam
# Processing Record 18 of Set 14 | loandjili
# Processing Record 19 of Set 14 | fairbanks
# Processing Record 20 of Set 14 | nouakchott
# Processing Record 21 of Set 14 | daru
# Processing Record 22 of Set 14 | beitbridge
# Processing Record 23 of Set 14 | tezu
# Processing Record 24 of Set 14 | praya
# Processing Record 25 of Set 14 | kupang
# Processing Record 26 of Set 14 | carauari
# Processing Record 27 of Set 14 | kysyl-syr
# Processing Record 28 of Set 14 | rupert
# Processing Record 29 of Set 14 | kidal
# Processing Record 30 of Set 14 | otjiwarongo
# Processing Record 31 of Set 14 | iwanai
# Processing Record 32 of Set 14 | tynda
# Processing Record 33 of Set 14 | pemangkat
# Processing Record 34 of Set 14 | swan river
# Processing Record 35 of Set 14 | aguimes
# Processing Record 36 of Set 14 | nicoya
# Processing Record 37 of Set 14 | pirgos
# Processing Record 38 of Set 14 | yevlax
# Processing Record 39 of Set 14 | jiaonan
# Processing Record 40 of Set 14 | antalaha
# Processing Record 41 of Set 14 | riorges
# Processing Record 42 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 44 of Set 14 | fare
# Processing Record 45 of Set 14 | vernon
# Processing Record 46 of Set 14 | margate
# Processing Record 47 of Set 14 | uyar
# Processing Record 48 of Set 14 | eyl
# Processing Record 49 of Set 14 | port-gentil
# Processing Record 50 of Set 14 | huainan
# Processing Record 1 of Set 15 | evensk
# Processing Record 2 of Set 15 | paita
# Processing Record 3 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 15 | chicama
# Processing Record 6 of Set 15 | acapulco
# Processing Record 7 of Set 15 | vestmannaeyjar
# Processing Record 8 of Set 15 | komsomolskiy
# Processing Record 9 of Set 15 | nabire
# Processing Record 10 of Set 15 | batemans bay
# Processing Record 11 of Set 15 | bagli
# Processing Record 12 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 15 | cururupu
# Processing Record 14 of Set 15 | havoysund
# Processing Record 15 of Set 15 | lata
# Processing Record 16 of Set 15 | tura
# Processing Record 17 of Set 15 | ejura
# Processing Record 18 of Set 15 | rawson
# Processing Record 19 of Set 15 | katsuura
# Processing Record 20 of Set 15 | zabid
# Processing Record 21 of Set 15 | brigantine
# Processing Record 22 of Set 15 | road town
# Processing Record 23 of Set 15 | fethiye
# Processing Record 24 of Set 15 | anchorage
# Processing Record 25 of Set 15 | kanker
# Processing Record 26 of Set 15 | cabra
# Processing Record 27 of Set 15 | banjar
# Processing Record 28 of Set 15 | arrecife
# Processing Record 29 of Set 15 | krasnoselkup
# Processing Record 30 of Set 15 | adrar
# Processing Record 31 of Set 15 | ust-koksa
# Processing Record 32 of Set 15 | yar-sale
# Processing Record 33 of Set 15 | jesus maria
# Processing Record 34 of Set 15 | san carlos
# Processing Record 35 of Set 15 | montepuez
# Processing Record 36 of Set 15 | xining
# Processing Record 37 of Set 15 | fomboni
# Processing Record 38 of Set 15 | pisco
# Processing Record 39 of Set 15 | krasnaya polyana
# Processing Record 40 of Set 15 | bahia blanca
# Processing Record 41 of Set 15 | eureka
# Processing Record 42 of Set 15 | kandrian
# Processing Record 43 of Set 15 | atlantic city
# Processing Record 44 of Set 15 | istanbul
# Processing Record 45 of Set 15 | kavaratti
# Processing Record 46 of Set 15 | qaqortoq
# Processing Record 47 of Set 15 | pilar
# Processing Record 48 of Set 15 | manutuke
# Processing Record 49 of Set 15 | carman
# Processing Record 50 of Set 15 | ambovombe
# Processing Record 1 of Set 16 | mikhaylovka
# Processing Record 2 of Set 16 | gisborne
# Processing Record 3 of Set 16 | ak-dovurak
# Processing Record 4 of Set 16 | inhambane
# Processing Record 5 of Set 16 | chilca
# Processing Record 6 of Set 16 | stokmarknes
# Processing Record 7 of Set 16 | ploemeur
# Processing Record 8 of Set 16 | harper
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     66.00        62          31
# 1         Lagoa  39.0500  -27.9833     60.01        87          95
# 2     Jamestown  42.0970  -79.2353     48.00        23          90
# 3  Puerto Ayora  -0.7393  -90.3518     82.40        74          20
# 4   Urozhaynoye  44.7883   44.9228     48.34        74          92
#
#    Wind Speed Country Current Description
# 0       13.00      NZ    scattered clouds
# 1       30.89      PT     overcast clouds
# 2       14.97      US     overcast clouds
# 3        9.22      EC          light rain
# 4        7.72      RU       moderate rain

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Mataura      NZ -46.1927  168.8643     66.00        62
# 1                     Lagoa      PT  39.0500  -27.9833     60.01        87
# 2                 Jamestown      US  42.0970  -79.2353     48.00        23
# 3              Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 4               Urozhaynoye      RU  44.7883   44.9228     48.34        74
# 5                  Medvedka      RU  61.1629   46.3870     25.34        96
# 6  Sao Jose Da Coroa Grande      BR  -8.8978  -35.1478     79.23        83
# 7                   Sibolga      ID   1.7427   98.7792     75.24        94
# 8                  Cidreira      BR -30.1811  -50.2056     72.97        75
# 9                  Cherskiy      RU  68.7500  161.3000     -8.19        93
#
#    Cloudiness  Wind Speed Current Description
# 0          31       13.00    scattered clouds
# 1          95       30.89     overcast clouds
# 2          90       14.97     overcast clouds
# 3          20        9.22          light rain
# 4          92        7.72       moderate rain
# 5          92        2.86     overcast clouds
# 6          17        8.34          few clouds
# 7         100        9.06     overcast clouds
# 8           0       14.43           clear sky
# 9          70        6.29       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
